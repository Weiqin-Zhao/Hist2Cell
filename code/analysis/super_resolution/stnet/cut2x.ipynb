# %%
import os
import pandas as pd

slide = "23209_C1"

spot_df = pd.read_csv(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/stnet", slide, "spots.csv"), index_col=0)
cell_abundance_df = pd.read_csv(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/stnet", slide, "cell_ratio.csv"), index_col=0)

# %%
from hmac import new


for index, row in spot_df.iterrows():
    x_int = int(index.split("x")[0])
    y_int = int(index.split("x")[1])
    
    if str(x_int - 1) + "x" + str(y_int - 1) in spot_df.index:
        new_x_int = x_int - 0.5
        new_y_int = y_int - 0.5
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int - 1) + "x" + str(y_int - 1)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int - 1) + "x" + str(y_int - 1)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
    
    if str(x_int - 1) + "x" + str(y_int) in spot_df.index:
        new_x_int = x_int - 0.5
        new_y_int = y_int
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int - 1) + "x" + str(y_int)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int - 1) + "x" + str(y_int)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}

    if str(x_int - 1) + "x" + str(y_int + 1) in spot_df.index:
        new_x_int = x_int - 0.5
        new_y_int = y_int + 0.5
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int - 1) + "x" + str(y_int + 1)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int - 1) + "x" + str(y_int + 1)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
            
    if str(x_int) + "x" + str(y_int - 1) in spot_df.index:
        new_x_int = x_int
        new_y_int = y_int - 0.5
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int) + "x" + str(y_int - 1)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int) + "x" + str(y_int - 1)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
            
    if str(x_int) + "x" + str(y_int + 1) in spot_df.index:
        new_x_int = x_int
        new_y_int = y_int + 0.5
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int) + "x" + str(y_int + 1)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int) + "x" + str(y_int + 1)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
    
    if str(x_int + 1) + "x" + str(y_int - 1) in spot_df.index:
        new_x_int = x_int + 0.5 
        new_y_int = y_int - 0.5
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int + 1) + "x" + str(y_int - 1)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int + 1) + "x" + str(y_int - 1)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
            
    if str(x_int + 1) + "x" + str(y_int) in spot_df.index:
        new_x_int = x_int + 0.5 
        new_y_int = y_int
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int + 1) + "x" + str(y_int)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int + 1) + "x" + str(y_int)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
            
    if str(x_int + 1) + "x" + str(y_int + 1) in spot_df.index:
        new_x_int = x_int + 0.5 
        new_y_int = y_int + 0.5
        if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
            new_x_pixel = (row['X']+spot_df.loc[str(x_int + 1) + "x" + str(y_int + 1)]['X'])/2
            new_y_pixel = (row['Y']+spot_df.loc[str(x_int + 1) + "x" + str(y_int + 1)]['Y'])/2
            spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}

# %%
spot_df.to_csv(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/stnet", slide, "2x_spots.csv"))

# %%
spot_df = pd.read_csv(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/stnet", slide, "spots.csv"), index_col=0)
spot_df_2x = pd.read_csv(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/stnet", slide, "2x_spots.csv"), index_col=0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.scatter(spot_df['X'], spot_df['Y'])

# 为图表添加标题和轴标签
plt.title('Scatter plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')

# 显示图表
plt.show()

# %%
plt.scatter(spot_df_2x['X'], spot_df_2x['Y'])

# 为图表添加标题和轴标签
plt.title('Scatter plot of X and Y')
plt.xlabel('X')
plt.ylabel('Y')

# 显示图表
plt.show()

# %%
from glob import glob

slide_list = glob("/data1/r20user3/shared_project/Hist2Cell/data/stnet/2*")
for slide_path in slide_list:
    slide = slide_path.split("/")[-1]
    
    spot_df = pd.read_csv(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/stnet", slide, "spots.csv"), index_col=0)
    for index, row in spot_df.iterrows():
        x_int = int(index.split("x")[0])
        y_int = int(index.split("x")[1])
        
        if str(x_int - 1) + "x" + str(y_int - 1) in spot_df.index:
            new_x_int = x_int - 0.5
            new_y_int = y_int - 0.5
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int - 1) + "x" + str(y_int - 1)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int - 1) + "x" + str(y_int - 1)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
        
        if str(x_int - 1) + "x" + str(y_int) in spot_df.index:
            new_x_int = x_int - 0.5
            new_y_int = y_int
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int - 1) + "x" + str(y_int)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int - 1) + "x" + str(y_int)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}

        if str(x_int - 1) + "x" + str(y_int + 1) in spot_df.index:
            new_x_int = x_int - 0.5
            new_y_int = y_int + 0.5
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int - 1) + "x" + str(y_int + 1)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int - 1) + "x" + str(y_int + 1)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
                
        if str(x_int) + "x" + str(y_int - 1) in spot_df.index:
            new_x_int = x_int
            new_y_int = y_int - 0.5
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int) + "x" + str(y_int - 1)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int) + "x" + str(y_int - 1)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
                
        if str(x_int) + "x" + str(y_int + 1) in spot_df.index:
            new_x_int = x_int
            new_y_int = y_int + 0.5
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int) + "x" + str(y_int + 1)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int) + "x" + str(y_int + 1)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
        
        if str(x_int + 1) + "x" + str(y_int - 1) in spot_df.index:
            new_x_int = x_int + 0.5 
            new_y_int = y_int - 0.5
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int + 1) + "x" + str(y_int - 1)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int + 1) + "x" + str(y_int - 1)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
                
        if str(x_int + 1) + "x" + str(y_int) in spot_df.index:
            new_x_int = x_int + 0.5 
            new_y_int = y_int
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int + 1) + "x" + str(y_int)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int + 1) + "x" + str(y_int)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
                
        if str(x_int + 1) + "x" + str(y_int + 1) in spot_df.index:
            new_x_int = x_int + 0.5 
            new_y_int = y_int + 0.5
            if str(new_x_int) + "x" + str(new_y_int) not in spot_df.index:
                new_x_pixel = (row['X']+spot_df.loc[str(x_int + 1) + "x" + str(y_int + 1)]['X'])/2
                new_y_pixel = (row['Y']+spot_df.loc[str(x_int + 1) + "x" + str(y_int + 1)]['Y'])/2
                spot_df.loc[str(new_x_int) + "x" + str(new_y_int)] = {"X": new_x_pixel, "Y": new_y_pixel}
    
    spot_df.to_csv(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/stnet", slide, "2x_spots.csv"))

# %%
from PIL import Image, ImageDraw
import csv

for slide_path in slide_list:
    slide = slide_path.split("/")[-1]
    img_path = glob(os.path.join(slide_path, slide+"*.jpg"))[0]
    img = Image.open(img_path)
    
    label_file_path = os.path.join(slide_path, '2x_spots.csv')
    label_file = open(label_file_path, 'r')

    patch_save_path = os.path.join(slide_path, "2x_patches")
    
    x_size = 112
    y_size = 112
    patch_size = 112
    
    result = []
    
    csv_reader = csv.reader(label_file)
    if not os.path.exists(patch_save_path):
        os.mkdir(patch_save_path)
    for id, x, y in csv_reader:
        if x == 'X':
            continue
        x = int(float(x))
        y = int(float(y))
        # result.append([id, x, y, clus_table[id]])
        result.append([id, x, y, 0])
        box = (x-x_size,y-y_size, x+x_size, y+y_size)
        # img.crop(box).save(os.path.join(patch_save_path, id + '.jpg'))

    label_file.close()

    color_list = [(94,38,18), (255,128,0), (225,225,0), (0,225,0), (0,225,225), (0,0,225), (25,25,112)]
    draw = ImageDraw.Draw(img)
    for name,x,y,clus in result:
        clus = int(clus)
        draw.ellipse((x-x_size/2,y-y_size/2, x+x_size/2, y+y_size/2), 'red', 'wheat')

    view_save_path = os.path.join(slide_path, "2x_spot_view.jpg")
    img.save(view_save_path)
    print(view_save_path)
# Out:
# /home/r20user3/anaconda3/envs/gene/lib/python3.11/site-packages/PIL/Image.py:3074: DecompressionBombWarning: Image size (91769216 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /data1/r20user3/shared_project/Hist2Cell/data/stnet/23287_C1/2x_spot_view.jpg
# /home/r20user3/anaconda3/envs/gene/lib/python3.11/site-packages/PIL/Image.py:3074: DecompressionBombWarning: Image size (92224860 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /data1/r20user3/shared_project/Hist2Cell/data/stnet/23277_E1/2x_spot_view.jpg
# /home/r20user3/anaconda3/envs/gene/lib/python3.11/site-packages/PIL/Image.py:3074: DecompressionBombWarning: Image size (91791569 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /data1/r20user3/shared_project/Hist2Cell/data/stnet/24044_D2/2x_spot_view.jpg
# ...

# %%
img_path
# Out:
# '/data1/r20user3/shared_project/Hist2Cell/data/stnet/23287_C1/23287_C1.jpg'
