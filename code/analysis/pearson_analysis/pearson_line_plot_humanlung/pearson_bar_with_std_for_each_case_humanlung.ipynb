# %%
import pickle
import statistics

# %%
from glob import glob
tif_list = glob('/data1/r20user3/shared_project/Hist2Cell/code/training/train_test_splits/humanlung_cell2location/test*')
tif_list.sort()
test_slides = list()
for tif in tif_list:
    tif_path = tif.split('_')[-1].split('.')[0]
    test_slides.append(tif_path)
test_slides
# Out:
# ['A37', 'A42', 'A48', 'A50']

# %%
import matplotlib.pyplot as plt
import numpy as np


case = "A50"
with open('/data1/r20user3/shared_project/Hist2Cell/code/training/pearson_log/humanlung_epoch100_lr1e-4_2hop_ensemble_onlycell_'+case+'_cell_pearson_list.pkl', 'rb') as f:
    multi_cell_pearson_list = pickle.load(f)
sorted_indices = np.argsort(multi_cell_pearson_list)[::-1]


for case in test_slides:
    with open('/data1/r20user3/shared_project/Hist2Cell/code/training/pearson_log/humanlung_epoch100_lr1e-4_2hop_ensemble_onlycell_'+case+'_cell_pearson_list.pkl', 'rb') as f:
        multi_cell_pearson_list = pickle.load(f)
        
    sorted_list = np.array(multi_cell_pearson_list)[sorted_indices].tolist()
    
    x = range(len(sorted_list )) 
    plt.plot(x, sorted_list , label=case, marker='o')

plt.legend()
plt.show()

# %%
for case in test_slides:
    with open('/data1/r20user3/shared_project/Hist2Cell/code/training/pearson_log/humanlung_epoch100_lr1e-4_2hop_ensemble_onlycell_'+case+'_cell_pearson_list.pkl', 'rb') as f:
        multi_cell_pearson_list = pickle.load(f)
    
    multi_cell_pearson_list.sort()
    x = range(len(sorted_list )) 
    plt.plot(x, multi_cell_pearson_list, label=case, marker='o')

plt.legend()
plt.show()
