# %%
from glob import glob

stnet_graph_path_list = glob("/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/*.pt")
stnet_graph_path_list
# Out:
# ['/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23209_D1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23895_D1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23277_E1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23288_E2.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23277_D2.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23895_C1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23803_E1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23506_D1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/stnet/23810_D2.pt',
# ...

# %%
import torch
from tqdm import tqdm

count = 0
for path in tqdm(stnet_graph_path_list):
    data = torch.load(path)
    count = count + data.x.shape[0]
count
# Out:
# 100%|██████████| 68/68 [02:47<00:00,  2.46s/it]
# 30655

# %%
from glob import glob

her2st_graph_path_list = glob("/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/*.pt")
her2st_graph_path_list
# Out:
# ['/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/D2.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/E3.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/A1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/E2.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/C1.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/D6.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/H3.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/G3.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/B3.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/her2st/A6.pt',
# ...

# %%
import torch
from tqdm import tqdm

count = 0
for path in tqdm(her2st_graph_path_list):
    data = torch.load(path)
    count = count + data.x.shape[0]
count
# Out:
# 100%|██████████| 36/36 [01:10<00:00,  1.95s/it]
# 13620

# %%
from glob import glob

lung_graph_path_list = glob("/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/*.pt")
lung_graph_path_list
# Out:
# ['/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP9258467.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP10193348.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP9258468.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP10193347.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP9258463.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP8759313.pt',
#  '/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP9258464.pt',
# ...

# %%
import torch
from tqdm import tqdm

count = 0
for path in tqdm(lung_graph_path_list):
    data = torch.load(path)
    count = count + data.x.shape[0]
count
# Out:
# 100%|██████████| 11/11 [02:24<00:00, 13.10s/it]
# 20770
