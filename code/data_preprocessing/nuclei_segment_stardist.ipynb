# %%
import os 
os.environ['CUDA_VISIBLE_DEVICES'] = '5'

from stardist.models import StarDist2D

model = StarDist2D.from_pretrained('2D_versatile_he')
# Out:
# 2023-12-06 20:37:35.491495: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-06 20:37:35.685058: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-06 20:37:35.802134: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import torch

data = torch.load("/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP8759311.pt")
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/nuclei_segment_stardist.ipynb Cell 2 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bworkstation_20/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/nuclei_segment_stardist.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import torch
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bworkstation_20/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/nuclei_segment_stardist.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> data = torch.load("/data1/r20user3/shared_project/Hist2Cell/code/data_preprocessing/rawimg_graph/human_lung_cell2location/WSA_LngSP8759311.pt")
# ...
