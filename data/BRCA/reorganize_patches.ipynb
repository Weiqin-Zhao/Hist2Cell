# %%
from glob import glob
import os
import shutil
from tqdm import tqdm

case_path_list = glob('/data1/r20user3/shared_project/Hist2Cell/data/BRCA/WSI/BRCA/single/BRCA/*')
for case_path in tqdm(case_path_list):
    patch_list = glob(case_path + '/*.jpeg')
    # os.mkdir(os.path.join(case_path, 'patches'))
    for patch in patch_list:
        shutil.move(patch, os.path.join(case_path, 'patches', os.path.basename(patch)))
        # print(patch)
        # print(os.path.join(case_path, 'patches', os.path.basename(patch)))
# Out:
# 100%|██████████| 880/880 [00:23<00:00, 36.73it/s]

# %%
from glob import glob
import os
import shutil
from tqdm import tqdm

case_path_list = glob('/data1/r20user3/shared_project/Hist2Cell/data/BRCA/WSI/BRCA/single/BRCA/*')
for case_path in tqdm(case_path_list):
    print(case_path)
    print(os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/brca", case_path.split('/')[-1]))
    shutil.move(case_path, os.path.join("/data1/r20user3/shared_project/Hist2Cell/data/brca", case_path.split('/')[-1]))
# Out:
# 100%|██████████| 880/880 [00:00<00:00, 21991.63it/s]
# /data1/r20user3/shared_project/Hist2Cell/data/BRCA/WSI/BRCA/single/BRCA/TCGA-A8-A09R-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/brca/TCGA-A8-A09R-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/BRCA/WSI/BRCA/single/BRCA/TCGA-E2-A1IE-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/brca/TCGA-E2-A1IE-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/BRCA/WSI/BRCA/single/BRCA/TCGA-AR-A1AT-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/brca/TCGA-AR-A1AT-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/BRCA/WSI/BRCA/single/BRCA/TCGA-A2-A0CP-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/brca/TCGA-A2-A0CP-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/BRCA/WSI/BRCA/single/BRCA/TCGA-XX-A89A-01Z-00-DX1
# /data1/r20user3/shared_project/Hist2Cell/data/brca/TCGA-XX-A89A-01Z-00-DX1
# ...
